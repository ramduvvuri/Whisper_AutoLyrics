# %%
# Cell 1: GPU check (do this FIRST, every time)
# !nvidia-smi
# !pip install torch

# import torch
# print(f"CUDA available: {torch.cuda.is_available()}")
# print(f"Device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
# print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# print(f"Torch: {torch.__version__}")
# Out:
# Sun May 10 17:08:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.86                 Driver Version: 581.86         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   52C    P8              3W /   55W |      72MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Cell 2: Mount Drive (for persistent storage of data + checkpoints)
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/autolyrics
# %cd /content/drive/MyDrive/autolyrics

# %%
# Cell 3: Clone your repo
# !git clone https://github.com/YOURNAME/autolyrics.git
# %cd autolyrics

# %%
# Cell 4: Install
# !pip install -q -r requirements.txt
# !pip install -q -e .

# %%
# Cell 5: HF auth (token from https://huggingface.co/settings/tokens — needs WRITE)
from huggingface_hub import login
login()  # paste token interactively, OR:
# import os; os.environ["HF_TOKEN"] = "hf_..."; login(token=os.environ["HF_TOKEN"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Cell 5: HF auth (token from https://huggingface.co/settings/tokens — needs WRITE)
# ----> 2 from huggingface_hub import login
#       3 login()  # paste token interactively, OR:
#       4 # import os; os.environ["HF_TOKEN"] = "hf_..."; login(token=os.environ["HF_TOKEN"])
#
# ModuleNotFoundError: No module named 'huggingface_hub'

# %%
# Cell 6: W&B auth (free account at wandb.ai)
import wandb
wandb.login()

# %%
# Cell 7: Sanity load
from transformers import WhisperProcessor, WhisperForConditionalGeneration
processor = WhisperProcessor.from_pretrained("openai/whisper-small")
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-small")
model.to("cuda")
print(f"Model loaded. Params: {sum(p.numel() for p in model.parameters())/1e6:.1f}M")
print(f"VRAM after load: {torch.cuda.memory_allocated()/1e9:.2f} GB")
